# %% [markdown]
# 46-881
# Data Exploration

# %% [markdown]
# ## Data exploration using the pandas library
#
#
# Import the pandas library with the standard alias 'pd'

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Let's say we've got a new dataset and want play with it.
#
# First, you need to open it:
#
# From the disk or or from the GitHub

# %% [markdown]
# From the disk:
# * Save your file into the Google Drive
# * Mount the drive
# * Open the file

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
dodgers_from_drive = pd.read_csv("dodgers.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dodgers_from_drive = pd.read_csv("dodgers.csv")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %% [markdown]
# Or from the GitHub:

# %%
# Replace with the raw URL of your CSV file on GitHub
url = 'https://raw.github.com/mportnykh25/Python1_public/main/'

# Read the CSV file into a pandas DataFrame
dodgers = pd.read_csv(url + "dodgers.csv")
usedcars = pd.read_csv(url + "usedcars.csv")

# %% [markdown]
# **%whos**
#
# This command lists all the variables currently defined in your session, as well as with their type, size, and value.

# %%
# %whos
# Out:
# Variable              Type         Data/Info
# --------------------------------------------
# dodgers               DataFrame       month  day  attend day<...>n\n[81 rows x 12 columns]
# dodgers_from_drive    DataFrame       month  day  attend day<...>n\n[81 rows x 12 columns]
# dodgers_from_drive3   DataFrame       month  day  attend day<...>n\n[81 rows x 12 columns]
# drive                 module       <module 'google.colab.dri<...>s/google/colab/drive.py'>
# np                    module       <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# pd                    module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# url                   str          https://raw.github.com/mp<...>kh25/Python1_public/main/
# usedcars              DataFrame         year model  price  m<...>n\n[150 rows x 6 columns]

# %% [markdown]
# **.head()**
#
# Let's have a look at the top 10 raws of the DataFrame using the head function

# %%
dodgers.head(15)
# Out:
#    month  day  attend day_of_week   opponent  temp   skies day_night cap  \
# 0    APR   10   56000     Tuesday    Pirates    67  Clear        Day  NO
# 1    APR   11   29729   Wednesday    Pirates    58  Cloudy     Night  NO
# 2    APR   12   28328    Thursday    Pirates    57  Cloudy     Night  NO
# 3    APR   13   31601      Friday     Padres    54  Cloudy     Night  NO
# 4    APR   14   46549    Saturday     Padres    57  Cloudy     Night  NO
# 5    APR   15   38359      Sunday     Padres    65  Clear        Day  NO
# 6    APR   23   26376      Monday     Braves    60  Cloudy     Night  NO
# 7    APR   24   44014     Tuesday     Braves    63  Cloudy     Night  NO
# 8    APR   25   26345   Wednesday     Braves    64  Cloudy     Night  NO
# 9    APR   27   44807      Friday  Nationals    66  Clear      Night  NO
# 10   APR   28   54242    Saturday  Nationals    71  Clear      Night  NO
# 11   APR   29   48753      Sunday  Nationals    74  Clear        Day  NO
# ...

# %% [markdown]
# **.info()**
#
#
# To get a quick summary of the dataframe, let's use .info() method/function

# %%
dodgers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        81 non-null     object
#  1   day          81 non-null     int64
#  2   attend       81 non-null     int64
#  3   day_of_week  81 non-null     object
#  4   opponent     81 non-null     object
#  5   temp         81 non-null     int64
#  6   skies        81 non-null     object
#  7   day_night    81 non-null     object
#  8   cap          81 non-null     object
#  9   shirt        81 non-null     object
#  10  fireworks    81 non-null     object
#  11  bobblehead   81 non-null     object
# dtypes: int64(3), object(9)
# memory usage: 7.7+ KB

# %%
# to only check the types, you can look at the dtypes attribute:
dodgers.dtypes
# Out:
# month          object
# day             int64
# attend          int64
# day_of_week    object
# opponent       object
# temp            int64
# skies          object
# day_night      object
# cap            object
# shirt          object
# fireworks      object
# bobblehead     object
# dtype: object

# %% [markdown]
# You can manually changes the type of course.
#
#
# For example:
#
#
# dataframe_name["col_name"]=dataframe_name["col_name"].astype(int)

# %% [markdown]
# To  look at a particular variable/column:

# %%
dodgers["attend"]
# Out:
# 0     56000
# 1     29729
# 2     28328
# 3     31601
# 4     46549
#       ...
# 76    40724
# 77    35607
# 78    33624
# 79    42473
# 80    34014
# Name: attend, Length: 81, dtype: int64

# %% [markdown]
# To look at multiple variables, pass a list of the variables you want to look at:

# %%
dodgers[["attend", "opponent"]]
# Out:
#     attend opponent
# 0    56000  Pirates
# 1    29729  Pirates
# 2    28328  Pirates
# 3    31601   Padres
# 4    46549   Padres
# ..     ...      ...
# 76   40724  Rockies
# 77   35607  Rockies
# 78   33624   Giants
# 79   42473   Giants
# 80   34014   Giants
#
# [81 rows x 2 columns]

# %% [markdown]
# # Summary statistics
#
# **.describe()**
#
# For the summary statistics use .describe()

# %%
dodgers.describe()
# Out:
#              day        attend       temp
# count  81.000000     81.000000  81.000000
# mean   16.135802  41040.074074  73.148148
# std     9.605666   8297.539460   8.317318
# min     1.000000  24312.000000  54.000000
# 25%     8.000000  34493.000000  67.000000
# 50%    15.000000  40284.000000  73.000000
# 75%    25.000000  46588.000000  79.000000
# max    31.000000  56000.000000  95.000000

# %% [markdown]
# If you want to know just some specific statistics, like min and max of a variable...

# %%
dodgers["attend"].min()
# Out:
# 24312

# %%
dodgers["attend"].max()
# Out:
# 56000

# %%
dodgers["attend"].median()
# Out:
# 40284.0

# %% [markdown]
# **.value_counts()**
#
# for the categorical variables

# %%
dodgers.value_counts()
# Out:
# month  day  attend  day_of_week  opponent   temp  skies   day_night  cap  shirt  fireworks  bobblehead
# APR    10   56000   Tuesday      Pirates    67    Clear   Day        NO   NO     NO         NO            1
#        11   29729   Wednesday    Pirates    58    Cloudy  Night      NO   NO     NO         NO            1
#        12   28328   Thursday     Pirates    57    Cloudy  Night      NO   NO     NO         NO            1
#        13   31601   Friday       Padres     54    Cloudy  Night      NO   NO     YES        NO            1
#        14   46549   Saturday     Padres     57    Cloudy  Night      NO   NO     NO         NO            1
#                                                                                                          ..
# SEP    15   42449   Saturday     Cardinals  95    Clear   Night      NO   NO     NO         NO            1
#        16   35754   Sunday       Cardinals  86    Clear   Day        NO   NO     NO         NO            1
# ...

# %%
dodgers.value_counts("day_of_week")
# Out:
# day_of_week
# Friday       13
# Saturday     13
# Sunday       13
# Tuesday      13
# Monday       12
# Wednesday    12
# Thursday      5
# Name: count, dtype: int64

# %% [markdown]
# Note, that Python is usually NOT sensitve to the quotation marks used: i.e. double " ..." or single '...'

# %%
dodgers.value_counts('day_of_week')
# Out:
# day_of_week
# Friday       13
# Saturday     13
# Sunday       13
# Tuesday      13
# Monday       12
# Wednesday    12
# Thursday      5
# Name: count, dtype: int64

# %% [markdown]
# **Quick Plots**
#
# For plots, we will use the Seaborn and Matplotlib libraries.
#
#
# Seaborn builds on Matplotlib.
#
# Seaborn is good when working with Pandas data frames.
#
# Matplotlib allows for more customization.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Histogram and Boxplots
#
# **sns.histplot()**
#
# ...are a way to look at the distributions
#
# we'll use sns.histplot and pass the dodgers DataFrame as the data argument. Next, we indicate which column we'd like to use as x by passing the column name: day_of_week

# %%
sns.histplot(data=dodgers, x="day_of_week")
# Out:
# <Axes: xlabel='day_of_week', ylabel='Count'>

# %%
sns.histplot(data=dodgers, x="attend")
# Out:
# <Axes: xlabel='attend', ylabel='Count'>

# %% [markdown]
# Saving the plot:
#
#
# # BE VERY careful here!!
#
#  By default, you will not get any error messages
#
#  if the file fig1.png already exists.
#
#  It will simply be overwritten!

# %%
sns.histplot(data=dodgers, x="attend", binwidth=5000)
plt.xlabel("Attendance")
plt.savefig('fig1.png')

# %% [markdown]
# ** Box Plot **

# %%
sns.boxplot(data=dodgers, x="attend")
# Out:
# <Axes: xlabel='attend'>

# %%
sns.boxplot(data=dodgers, x="attend")
print("min=" , dodgers["attend"].min())
print("max=" , dodgers["attend"].max())
print("median=" , dodgers["attend"].median())
# Out:
# min= 24312
# max= 56000
# median= 40284.0

# %% [markdown]
# We can look at the attendance by the day of the week:

# %%
sns.boxplot(data=dodgers, x="day_of_week", y="attend")
plt.show()

# %%
sns.boxplot(data=dodgers, y="day_of_week", x="attend")
plt.xlabel("Attendance")
plt.ylabel("Day of the Week")
plt.title("Attendance by Day of the Week")
plt.show()

# %% [markdown]
# # Practice!
#
# Use usedcars.csv file
#
# *   Load the file, name the dataframe "usedcars"
# *   Are there any missing data?
# *   All correct types?
# *   Examine the summary statistics of the numerical variables
# *   Are there any categorical variables?
# *   Create a histogram showing the distribution of car prices

# %% [markdown]
# # Sorting

# %% [markdown]
# Suppose we want to sort the game by attendance:

# %%
# by default, it will be from the smallest to the largest
dodgers.sort_values("attend")
# Out:
#    month  day  attend day_of_week opponent  temp   skies day_night cap shirt  \
# 18   MAY   14   24312      Monday   Snakes    67  Clear      Night  NO    NO
# 28   MAY   30   25509   Wednesday  Brewers    69  Clear      Night  NO    NO
# 8    APR   25   26345   Wednesday   Braves    64  Cloudy     Night  NO    NO
# 6    APR   23   26376      Monday   Braves    60  Cloudy     Night  NO    NO
# 29   MAY   31   26773    Thursday  Brewers    70  Clear      Night  NO    NO
# ..   ...  ...     ...         ...      ...   ...     ...       ...  ..   ...
# 56   AUG    7   55024     Tuesday  Rockies    80  Clear      Night  NO    NO
# 31   JUN   12   55279     Tuesday   Angels    66  Cloudy     Night  NO    NO
# 39   JUL    1   55359      Sunday     Mets    75  Clear      Night  NO    NO
# 0    APR   10   56000     Tuesday  Pirates    67  Clear        Day  NO    NO
# 59   AUG   21   56000     Tuesday   Giants    75  Clear      Night  NO    NO
#
#    fireworks bobblehead
# ...

# %%
#add option "ascending = False", to sort in decreasing order
dodgers.sort_values("attend", ascending = False)
# Out:
#    month  day  attend day_of_week opponent  temp   skies day_night cap shirt  \
# 0    APR   10   56000     Tuesday  Pirates    67  Clear        Day  NO    NO
# 59   AUG   21   56000     Tuesday   Giants    75  Clear      Night  NO    NO
# 39   JUL    1   55359      Sunday     Mets    75  Clear      Night  NO    NO
# 31   JUN   12   55279     Tuesday   Angels    66  Cloudy     Night  NO    NO
# 56   AUG    7   55024     Tuesday  Rockies    80  Clear      Night  NO    NO
# ..   ...  ...     ...         ...      ...   ...     ...       ...  ..   ...
# 29   MAY   31   26773    Thursday  Brewers    70  Clear      Night  NO    NO
# 6    APR   23   26376      Monday   Braves    60  Cloudy     Night  NO    NO
# 8    APR   25   26345   Wednesday   Braves    64  Cloudy     Night  NO    NO
# 28   MAY   30   25509   Wednesday  Brewers    69  Clear      Night  NO    NO
# 18   MAY   14   24312      Monday   Snakes    67  Clear      Night  NO    NO
#
#    fireworks bobblehead
# ...

# %% [markdown]
# Note that the original dataframe is not sorted, it stays the same.
#
#
# Several of the DataFrame methods support the optional parameter **`inplace`**, which allows to change the DataFrame directly by means of a given operation.
#
# By adding it in this case, we will sort the original DataFrame.

# %%
dodgers.sort_values("attend", ascending = False, inplace=True)
dodgers.head(10)
# Out:
#    month  day  attend day_of_week   opponent  temp   skies day_night cap  \
# 0    APR   10   56000     Tuesday    Pirates    67  Clear        Day  NO
# 59   AUG   21   56000     Tuesday     Giants    75  Clear      Night  NO
# 39   JUL    1   55359      Sunday       Mets    75  Clear      Night  NO
# 31   JUN   12   55279     Tuesday     Angels    66  Cloudy     Night  NO
# 56   AUG    7   55024     Tuesday    Rockies    80  Clear      Night  NO
# 64   AUG   30   54621    Thursday     Snakes    80  Clear      Night  NO
# 10   APR   28   54242    Saturday  Nationals    71  Clear      Night  NO
# 44   JUL   14   54014    Saturday     Padres    75  Clear      Night  NO
# 42   JUL    4   53570   Wednesday       Reds    70  Clear      Night  NO
# 35   JUN   17   53504      Sunday  White Sox    74  Clear        Day  NO
#
#    shirt fireworks bobblehead
# 0     NO        NO         NO
# 59    NO        NO        YES
# 39    NO        NO        YES
# 31    NO        NO        YES
# ...

# %% [markdown]
# # Filtering
#
# Let's find games that happened on Saturdays and Sundays.
#
# First, let's see if we have Saturdays or Sundays games using
#
#
# ***.isin() method**
#
# # Recall %in% in R
#
# The .isin() function returns a Series of the same size and shape, as the original but with True and False in place of all values, depending on whether the value from the original Series was included in the list passed, i.e.
# whetehr the games was on Saturdays or Sundays.

# %%
dodgers["day_of_week"].isin(["Saturday", "Sunday"])
# Out:
# 0     False
# 59    False
# 39     True
# 31    False
# 56    False
#       ...
# 29    False
# 6     False
# 8     False
# 28    False
# 18    False
# Name: day_of_week, Length: 81, dtype: bool

# %% [markdown]
# Use the tilde operator at the beginning of the code block to invert the True/ False values so that the function returns True if the value is NOT in the list passed

# %%
~dodgers["day_of_week"].isin(["Saturday", "Sunday"])
# Out:
# 0      True
# 59     True
# 39    False
# 31     True
# 56     True
#       ...
# 29     True
# 6      True
# 8      True
# 28     True
# 18     True
# Name: day_of_week, Length: 81, dtype: bool

# %% [markdown]
# Let's keep only the Saturdays or Sundays games. Let's create a new dataframe, call it "dodgersSS"

# %%
dodgersSS=dodgers[dodgers["day_of_week"].isin(["Saturday", "Sunday"])]
print(dodgersSS.info())
print(dodgersSS.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 39 to 67
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        26 non-null     object
#  1   day          26 non-null     int64
#  2   attend       26 non-null     int64
#  3   day_of_week  26 non-null     object
#  4   opponent     26 non-null     object
#  5   temp         26 non-null     int64
#  6   skies        26 non-null     object
#  7   day_night    26 non-null     object
#  8   cap          26 non-null     object
#  9   shirt        26 non-null     object
#  10  fireworks    26 non-null     object
#  11  bobblehead   26 non-null     object
# dtypes: int64(3), object(9)
# memory usage: 2.6+ KB
# None
#    month  day  attend day_of_week   opponent  temp   skies day_night cap  \
# 39   JUL    1   55359      Sunday       Mets    75  Clear      Night  NO
# 10   APR   28   54242    Saturday  Nationals    71  Clear      Night  NO
# ...

# %% [markdown]
# Filtering based on logical tests.

# %%
dodgers40K=dodgers[dodgers["attend"] >= 40000]
dodgers40K.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43 entries, 0 to 72
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        43 non-null     object
#  1   day          43 non-null     int64
#  2   attend       43 non-null     int64
#  3   day_of_week  43 non-null     object
#  4   opponent     43 non-null     object
#  5   temp         43 non-null     int64
#  6   skies        43 non-null     object
#  7   day_night    43 non-null     object
#  8   cap          43 non-null     object
#  9   shirt        43 non-null     object
#  10  fireworks    43 non-null     object
#  11  bobblehead   43 non-null     object
# dtypes: int64(3), object(9)
# memory usage: 4.4+ KB

# %% [markdown]
# Index: 43 entries, 0 to 72?
# Why?

# %%
dodgers40K.head()
# Out:
#    month  day  attend day_of_week opponent  temp   skies day_night cap shirt  \
# 0    APR   10   56000     Tuesday  Pirates    67  Clear        Day  NO    NO
# 59   AUG   21   56000     Tuesday   Giants    75  Clear      Night  NO    NO
# 39   JUL    1   55359      Sunday     Mets    75  Clear      Night  NO    NO
# 31   JUN   12   55279     Tuesday   Angels    66  Cloudy     Night  NO    NO
# 56   AUG    7   55024     Tuesday  Rockies    80  Clear      Night  NO    NO
#
#    fireworks bobblehead
# 0         NO         NO
# 59        NO        YES
# 39        NO        YES
# 31        NO        YES
# 56        NO        YES

# %% [markdown]
# The indicies are the same as in the origianl dataframe.
#
#
# If you want re-index - reset the index:

# %%
dodgers40K = dodgers[dodgers["attend"] >= 40000].reset_index(drop=True)
dodgers40K.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        43 non-null     object
#  1   day          43 non-null     int64
#  2   attend       43 non-null     int64
#  3   day_of_week  43 non-null     object
#  4   opponent     43 non-null     object
#  5   temp         43 non-null     int64
#  6   skies        43 non-null     object
#  7   day_night    43 non-null     object
#  8   cap          43 non-null     object
#  9   shirt        43 non-null     object
#  10  fireworks    43 non-null     object
#  11  bobblehead   43 non-null     object
# dtypes: int64(3), object(9)
# memory usage: 4.2+ KB

# %% [markdown]
# # Practice!
#
# *   Create a new DataFrame without Black cars
# * Sort the resulting DataFrame by price in increasing order

# %% [markdown]
# # Select

# %% [markdown]
# Let's keep only two variables: attendance and opponent

# %%
dodgers.head()
# Out:
#    month  day  attend day_of_week opponent  temp   skies day_night cap shirt  \
# 0    APR   10   56000     Tuesday  Pirates    67  Clear        Day  NO    NO
# 59   AUG   21   56000     Tuesday   Giants    75  Clear      Night  NO    NO
# 39   JUL    1   55359      Sunday     Mets    75  Clear      Night  NO    NO
# 31   JUN   12   55279     Tuesday   Angels    66  Cloudy     Night  NO    NO
# 56   AUG    7   55024     Tuesday  Rockies    80  Clear      Night  NO    NO
#
#    fireworks bobblehead
# 0         NO         NO
# 59        NO        YES
# 39        NO        YES
# 31        NO        YES
# 56        NO        YES

# %%
dodgers[["attend", "opponent"]]
# Out:
#     attend opponent
# 0    56000  Pirates
# 59   56000   Giants
# 39   55359     Mets
# 31   55279   Angels
# 56   55024  Rockies
# ..     ...      ...
# 29   26773  Brewers
# 6    26376   Braves
# 8    26345   Braves
# 28   25509  Brewers
# 18   24312   Snakes
#
# [81 rows x 2 columns]

# %%
#or cteate a list of cols to keep and then use that list
cols_keep=["attend", "opponent"]
dodgers[cols_keep]
# Out:
#     attend opponent
# 0    56000  Pirates
# 59   56000   Giants
# 39   55359     Mets
# 31   55279   Angels
# 56   55024  Rockies
# ..     ...      ...
# 29   26773  Brewers
# 6    26376   Braves
# 8    26345   Braves
# 28   25509  Brewers
# 18   24312   Snakes
#
# [81 rows x 2 columns]

# %% [markdown]
# Or using matrix notation - aka slicing

# %%
#let's remind outself about the variables we have
dodgers.columns
# Out:
# Index(['month', 'day', 'attend', 'day_of_week', 'opponent', 'temp', 'skies',
#        'day_night', 'cap', 'shirt', 'fireworks', 'bobblehead'],
#       dtype='object')

# %%
dodgers.iloc[:, [0, 1, 2, 3]]
# Out:
#    month  day  attend day_of_week
# 0    APR   10   56000     Tuesday
# 59   AUG   21   56000     Tuesday
# 39   JUL    1   55359      Sunday
# 31   JUN   12   55279     Tuesday
# 56   AUG    7   55024     Tuesday
# ..   ...  ...     ...         ...
# 29   MAY   31   26773    Thursday
# 6    APR   23   26376      Monday
# 8    APR   25   26345   Wednesday
# 28   MAY   30   25509   Wednesday
# 18   MAY   14   24312      Monday
#
# [81 rows x 4 columns]

# %%
dodgers.iloc[:, [0, 2, 5]]
# Out:
#    month  attend  temp
# 0    APR   56000    67
# 59   AUG   56000    75
# 39   JUL   55359    75
# 31   JUN   55279    66
# 56   AUG   55024    80
# ..   ...     ...   ...
# 29   MAY   26773    70
# 6    APR   26376    60
# 8    APR   26345    64
# 28   MAY   25509    69
# 18   MAY   24312    67
#
# [81 rows x 3 columns]

# %%
dodgers.iloc[0:3, [0, 1, 2, 3]]
# Out:
#    month  day  attend day_of_week
# 0    APR   10   56000     Tuesday
# 59   AUG   21   56000     Tuesday
# 39   JUL    1   55359      Sunday

# %%
#month,	day	attend, attend,	and opponnet for the top 3 attended games
dodgers.sort_values("attend", ascending=False).iloc[0:3, [0, 1, 2, 4]]
# Out:
#    month  day  attend opponent
# 0    APR   10   56000  Pirates
# 59   AUG   21   56000   Giants
# 39   JUL    1   55359     Mets

# %% [markdown]
# # Practice!
#
# Create a new DataFrame with the 3 most expensive white cars and 3 least expensive blue cars.

# %% [markdown]
# # Summary by groups
#
# groupby() groups data by category
#
# use aggregating function to compute summary statistics by groups
#
# `dodgers.groupby("day_of_week").mean()` will return an error. ***Why?***
#
#
#
# *Ans:* The groupby() operation calculates the mean for all applicable columns within each group. But the dodgers DataFrame contains several categorical variables. One cannot compute the means for all variables!
#
# What do you think this will return?
#
# `dodgers.groupby("day_of_week").mean("attend")`
#
# Run it!

# %%
dodgers.groupby("day_of_week").mean("attend")
# Out:
#                    day        attend       temp
# day_of_week
# Friday       19.307692  40116.923077  69.692308
# Monday       13.416667  34965.666667  72.833333
# Saturday     17.923077  43072.923077  72.692308
# Sunday       16.615385  42268.846154  78.153846
# Thursday     22.800000  40407.400000  72.400000
# Tuesday      14.076923  47741.230769  72.769231
# Wednesday    12.416667  37585.166667  73.000000

# %% [markdown]
# The mean aggregation applied to all numerical columns...
#
# To find the mean  ONLY for the 'attend' column for each group:
#
# Group by 'day_of_week' and then select the 'attend' column to calculate its mean

# %%
dodgers.groupby("day_of_week")["attend"].mean()
# Out:
# day_of_week
# Friday       40116.923077
# Monday       34965.666667
# Saturday     43072.923077
# Sunday       42268.846154
# Thursday     40407.400000
# Tuesday      47741.230769
# Wednesday    37585.166667
# Name: attend, dtype: float64

# %%
dodgers_attend_mean_by_day = dodgers.groupby("day_of_week")["attend"].mean()
print(dodgers_attend_mean_by_day)
# Out:
# day_of_week
# Friday       40116.923077
# Monday       34965.666667
# Saturday     43072.923077
# Sunday       42268.846154
# Thursday     40407.400000
# Tuesday      47741.230769
# Wednesday    37585.166667
# Name: attend, dtype: float64

# %% [markdown]
# **Other aggregating functions:
#
#
# *   Sum: .sum()
# *   Minumum: .min()
# *   Maximum: .max()
# *   Count: .count()
# *   Variance: .var()
# *   Standard deviation: .std()
# *   Median: .median()

# %%
dodgers.groupby("day_of_week")["attend"].median()
# Out:
# day_of_week
# Friday       40167.0
# Monday       33582.0
# Saturday     42449.0
# Sunday       41907.0
# Thursday     43309.0
# Tuesday      51137.0
# Wednesday    36840.0
# Name: attend, dtype: float64

# %% [markdown]
# ** .agg() **
#
# If we want to compute more than one sum stats at once, we can use .agg() method,
#
# passing a list of statistics we want to compute.

# %%
dodgers["attend"].agg(["mean","median"])
# Out:
# mean      41040.074074
# median    40284.000000
# Name: attend, dtype: float64

# %%
dodgers[["attend","temp"]].agg(["mean","median"])
# Out:
#               attend       temp
# mean    41040.074074  73.148148
# median  40284.000000  73.000000

# %% [markdown]
# Now let's compute sum stats for the attendance by the day of the week variable:

# %%
dodgers.groupby("day_of_week")["attend"].agg(["mean","median"])
# Out:
#                      mean   median
# day_of_week
# Friday       40116.923077  40167.0
# Monday       34965.666667  33582.0
# Saturday     43072.923077  42449.0
# Sunday       42268.846154  41907.0
# Thursday     40407.400000  43309.0
# Tuesday      47741.230769  51137.0
# Wednesday    37585.166667  36840.0

# %%
dodgers.groupby("day_of_week")[["attend", "temp"]].agg(["mean","median"])
# Out:
#                    attend                temp
#                      mean   median       mean median
# day_of_week
# Friday       40116.923077  40167.0  69.692308   71.0
# Monday       34965.666667  33582.0  72.833333   71.5
# Saturday     43072.923077  42449.0  72.692308   71.0
# Sunday       42268.846154  41907.0  78.153846   77.0
# Thursday     40407.400000  43309.0  72.400000   75.0
# Tuesday      47741.230769  51137.0  72.769231   74.0
# Wednesday    37585.166667  36840.0  73.000000   73.0

# %%
dodgers.groupby("day_of_week")[["attend", "temp"]].agg("mean")
# Out:
#                    attend       temp
# day_of_week
# Friday       40116.923077  69.692308
# Monday       34965.666667  72.833333
# Saturday     43072.923077  72.692308
# Sunday       42268.846154  78.153846
# Thursday     40407.400000  72.400000
# Tuesday      47741.230769  72.769231
# Wednesday    37585.166667  73.000000

# %% [markdown]
# We can create names for the columns...by creating named tuples inside the .agg() function.
#
# Each named tuple should include a column name followed by the aggregating function to apply to that column. The name of the tuple will be the name of the resulting column.

# %%
dodgers.groupby("day_of_week")[["attend", "temp"]].agg(
    mean_attend=("attend", "mean"),
    mean_temp=("temp", "mean")
)
# Out:
#               mean_attend  mean_temp
# day_of_week
# Friday       40116.923077  69.692308
# Monday       34965.666667  72.833333
# Saturday     43072.923077  72.692308
# Sunday       42268.846154  78.153846
# Thursday     40407.400000  72.400000
# Tuesday      47741.230769  72.769231
# Wednesday    37585.166667  73.000000

# %%
sum_stats1=dodgers.groupby("day_of_week")[["attend", "temp"]].agg(
    mean_attend=("attend", "mean"),
    mean_temp=("temp", "mean")
)
print(sum_stats1)
# Out:
#               mean_attend  mean_temp
# day_of_week
# Friday       40116.923077  69.692308
# Monday       34965.666667  72.833333
# Saturday     43072.923077  72.692308
# Sunday       42268.846154  78.153846
# Thursday     40407.400000  72.400000
# Tuesday      47741.230769  72.769231
# Wednesday    37585.166667  73.000000

# %%
dodgers.groupby("day_of_week")["attend"].agg(
    mean_attend="mean",
    median_attend="median"
)
# Out:
#               mean_attend  median_attend
# day_of_week
# Friday       40116.923077        40167.0
# Monday       34965.666667        33582.0
# Saturday     43072.923077        42449.0
# Sunday       42268.846154        41907.0
# Thursday     40407.400000        43309.0
# Tuesday      47741.230769        51137.0
# Wednesday    37585.166667        36840.0

# %%
sns.barplot(data=dodgers, x="day_of_week", y="attend")
plt.show()

# %% [markdown]
# Note that .agg() function collapses the data by group, giving you summary statistics for each group. So you end up with a smaller result table than your original data.
#
# Use **.transform()**to perform a group-specific calculation and return a result that has the same index as the original DataFrame. We will look at the example of .transform() later.

# %% [markdown]
# # Practice!
#
#
# 1.   Keep only black, white, and silver cars
# 2.   Print the mean and standard deviation of the price by year
# 2.   Print the mean and standard deviation of the price by year by car model
# 1.   Save the results into the new dataframe

# %% [markdown]
# # Missing data
#
# Let's create a demo dataset:

# %%
demo_data = pd.DataFrame({
    'year': [2021, 2023, 2023, 2024, 2025],
    'population': [100, 200, None, None, 500]
})
print(demo_data)
demo_data.head(5)
# Out:
#    year  population
# 0  2021       100.0
# 1  2023       200.0
# 2  2023         NaN
# 3  2024         NaN
# 4  2025       500.0
#    year  population
# 0  2021       100.0
# 1  2023       200.0
# 2  2023         NaN
# 3  2024         NaN
# 4  2025       500.0

# %% [markdown]
# How we can check if we have any missing data?

# %%
demo_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        5 non-null      int64
#  1   population  3 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 212.0 bytes

# %% [markdown]
# Another way is to use the .isna() function

# %%
demo_data.isna()
# Out:
#     year  population
# 0  False       False
# 1  False       False
# 2  False        True
# 3  False        True
# 4  False       False

# %%
~demo_data.isna()
# Out:
#    year  population
# 0  True        True
# 1  True        True
# 2  True       False
# 3  True       False
# 4  True        True

# %% [markdown]
# We can count the number of missing values per column/variable by **chaining** the .isna() and .sum() methods:

# %%
demo_data.isna().sum()
# Out:
# year          0
# population    2
# dtype: int64

# %% [markdown]
# As alwasy, one way to deal with missing data is just to drop the observations with missing data....
#
# But suppose you want to replace them with some values instead,
#
# i.e. some summary statistics.
#
# Let's replace the missing values with the mean.
# To do that we wil use ** .fillna()** method

# %%
demo_data["population"].fillna(demo_data["population"].mean())
# Out:
# 0    100.000000
# 1    200.000000
# 2    266.666667
# 3    266.666667
# 4    500.000000
# Name: population, dtype: float64

# %% [markdown]
# # Unique
#
# We can count how many unique job titles there are using pandas .nunique() method

# %%
dodgers.nunique()
# Out:
# month           7
# day            31
# attend         80
# day_of_week     7
# opponent       17
# temp           32
# skies           2
# day_night       2
# cap             2
# shirt           2
# fireworks       2
# bobblehead      2
# dtype: int64

# %%
dodgers["day_of_week"].str.contains("Saturday")
# Out:
# 0     False
# 59    False
# 39    False
# 31    False
# 56    False
#       ...
# 29    False
# 6     False
# 8     False
# 28    False
# 18    False
# Name: day_of_week, Length: 81, dtype: bool

# %%
dodgers["day_of_week"].str.contains("S")
# Out:
# 0     False
# 59    False
# 39     True
# 31    False
# 56    False
#       ...
# 29    False
# 6     False
# 8     False
# 28    False
# 18    False
# Name: day_of_week, Length: 81, dtype: bool

# %%
dodgers.head(10)
# Out:
#    month  day  attend day_of_week   opponent  temp   skies day_night cap  \
# 0    APR   10   56000     Tuesday    Pirates    67  Clear        Day  NO
# 59   AUG   21   56000     Tuesday     Giants    75  Clear      Night  NO
# 39   JUL    1   55359      Sunday       Mets    75  Clear      Night  NO
# 31   JUN   12   55279     Tuesday     Angels    66  Cloudy     Night  NO
# 56   AUG    7   55024     Tuesday    Rockies    80  Clear      Night  NO
# 64   AUG   30   54621    Thursday     Snakes    80  Clear      Night  NO
# 10   APR   28   54242    Saturday  Nationals    71  Clear      Night  NO
# 44   JUL   14   54014    Saturday     Padres    75  Clear      Night  NO
# 42   JUL    4   53570   Wednesday       Reds    70  Clear      Night  NO
# 35   JUN   17   53504      Sunday  White Sox    74  Clear        Day  NO
#
#    shirt fireworks bobblehead
# 0     NO        NO         NO
# 59    NO        NO        YES
# 39    NO        NO        YES
# 31    NO        NO        YES
# ...

# %% [markdown]
# # Add a new column
#
# Let's add a new column 'weekend_game' indicating games happend on Saturday or Sunday
#
# Steps:
#
# 1. Use .str.contains "Saturday|Sunday" to find weekend days
# 2. Convert the boolean result (True/False) to integers (1/0) using .astype(int)

# %%
dodgers['weekend_game'] = (
    dodgers["day_of_week"]
     .str.contains("Saturday|Sunday")
)
print(dodgers.head())

dodgers['is_weekend'] = (
    dodgers["day_of_week"]
    .str.contains("Saturday|Sunday")
    .astype(int)
)
# Out:
#    month  day  attend day_of_week opponent  temp   skies day_night cap shirt  \
# 0    APR   10   56000     Tuesday  Pirates    67  Clear        Day  NO    NO
# 59   AUG   21   56000     Tuesday   Giants    75  Clear      Night  NO    NO
# 39   JUL    1   55359      Sunday     Mets    75  Clear      Night  NO    NO
# 31   JUN   12   55279     Tuesday   Angels    66  Cloudy     Night  NO    NO
# 56   AUG    7   55024     Tuesday  Rockies    80  Clear      Night  NO    NO
#
#    fireworks bobblehead  weekend_game  is_weekend
# 0         NO         NO         False           0
# 59        NO        YES         False           0
# 39        NO        YES          True           1
# 31        NO        YES         False           0
# 56        NO        YES         False           0

# %% [markdown]
# # Practice!
#
# Use the used cars dataframe.
# 1. Add a new variable to the dataframe: the mean of price by car color.
# 2. Add a new variable to the dataframe: the count of cars by car color.

# %%
usedcars['mean_price_by_color'] = usedcars.groupby('color')['price'].transform('mean')


usedcars['count_by_color'] = usedcars.groupby('color')['price'].transform('count')

print(usedcars.head())
# Out:
#    year model  price  mileage   color transmission  mean_price_by_color  \
# 0  2011   SEL  21992     7413  Yellow         AUTO          11630.00000
# 1  2011   SEL  20995    10926    Gray         AUTO          13665.50000
# 2  2011   SEL  19995     7351  Silver         AUTO          13615.96875
# 3  2011   SEL  17809    11613    Gray         AUTO          13665.50000
# 4  2012    SE  17500     8367   White         AUTO          12394.18750
#
#    count_by_color
# 0               3
# 1              16
# 2              32
# 3              16
# 4              16

# %% [markdown]
# More reading
#
# To explore all this in (much) greater detail, check out the following chapters:
#
# https://pandas.pydata.org/docs/getting_started/comparison/comparison_with_r.html
# https://wesmckinney.com/book/pandas-basics
# https://wesmckinney.com/book/data-cleaning
# https://wesmckinney.com/book/data-wrangling
# https://wesmckinney.com/book/data-aggregation
